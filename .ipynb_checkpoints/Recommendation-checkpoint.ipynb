# %% [markdown]
# <h1><b>Libraries import</b></h1>

# %%
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# <h1><b>Load data</b></h1>

# %%
df_order_items = pd.read_csv('DNC_order_items_dataset.csv',index_col='Unnamed: 0')
df_order_reviews = pd.read_csv('DNC_order_reviews_dataset.csv',index_col='Unnamed: 0')
df_orders = pd.read_csv('DNC_orders_dataset.csv',index_col='Unnamed: 0')
df_products = pd.read_csv('DNC_products_dataset.csv',index_col='Unnamed: 0')

# %%
display(df_order_items.head().style)
print(f'shape is: {df_order_items.shape}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_1f4a8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >order_id</th>
#       <th class="col_heading level0 col1" >order_item_id</th>
#       <th class="col_heading level0 col2" >product_id</th>
#       <th class="col_heading level0 col3" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f4a8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1f4a8_row0_col0" class="data row0 col0" >00010242fe8c5a6d1ba2dd792cb16214</td>
#       <td id="T_1f4a8_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_1f4a8_row0_col2" class="data row0 col2" >4244733e06e7ecb4970a6e2683c13e61</td>
#       <td id="T_1f4a8_row0_col3" class="data row0 col3" >58.900000</td>
#     </tr>
#     <tr>
#       <th id="T_1f4a8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1f4a8_row1_col0" class="data row1 col0" >00018f77f2f0320c557190d7a144bdd3</td>
#       <td id="T_1f4a8_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_1f4a8_row1_col2" class="data row1 col2" >e5f2d52b802189ee658865ca93d83a8f</td>
#       <td id="T_1f4a8_row1_col3" class="data row1 col3" >239.900000</td>
#     </tr>
#     <tr>
#       <th id="T_1f4a8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1f4a8_row2_col0" class="data row2 col0" >000229ec398224ef6ca0657da4fc703e</td>
#       <td id="T_1f4a8_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_1f4a8_row2_col2" class="data row2 col2" >c777355d18b72b67abbeef9df44fd0fd</td>
#       <td id="T_1f4a8_row2_col3" class="data row2 col3" >199.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1f4a8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1f4a8_row3_col0" class="data row3 col0" >00024acbcdf0a6daa1e931b038114c75</td>
#       <td id="T_1f4a8_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_1f4a8_row3_col2" class="data row3 col2" >7634da152a4610f1595efa32f14722fc</td>
#       <td id="T_1f4a8_row3_col3" class="data row3 col3" >12.990000</td>
#     </tr>
#     <tr>
#       <th id="T_1f4a8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1f4a8_row4_col0" class="data row4 col0" >00042b26cf59d7ce69dfabb4e55b4fd9</td>
#       <td id="T_1f4a8_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_1f4a8_row4_col2" class="data row4 col2" >ac6c3623068f30de03045865e4e10089</td>
#       <td id="T_1f4a8_row4_col3" class="data row4 col3" >199.900000</td>
#     </tr>
#   </tbody>
# </table>
# shape is: (112650, 4)

# %%
display(df_order_reviews.head().style)
print(f'shape is: {df_order_reviews.shape}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_c5108_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >review_id</th>
#       <th class="col_heading level0 col1" >order_id</th>
#       <th class="col_heading level0 col2" >review_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c5108_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c5108_row0_col0" class="data row0 col0" >7bc2406110b926393aa56f80a40eba40</td>
#       <td id="T_c5108_row0_col1" class="data row0 col1" >73fc7af87114b39712e6da79b0a377eb</td>
#       <td id="T_c5108_row0_col2" class="data row0 col2" >4</td>
#     </tr>
#     <tr>
#       <th id="T_c5108_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c5108_row1_col0" class="data row1 col0" >80e641a11e56f04c1ad469d5645fdfde</td>
#       <td id="T_c5108_row1_col1" class="data row1 col1" >a548910a1c6147796b98fdf73dbeba33</td>
#       <td id="T_c5108_row1_col2" class="data row1 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_c5108_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c5108_row2_col0" class="data row2 col0" >228ce5500dc1d8e020d8d1322874b6f0</td>
#       <td id="T_c5108_row2_col1" class="data row2 col1" >f9e4b658b201a9f2ecdecbb34bed034b</td>
#       <td id="T_c5108_row2_col2" class="data row2 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_c5108_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c5108_row3_col0" class="data row3 col0" >e64fb393e7b32834bb789ff8bb30750e</td>
#       <td id="T_c5108_row3_col1" class="data row3 col1" >658677c97b385a9be170737859d3511b</td>
#       <td id="T_c5108_row3_col2" class="data row3 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_c5108_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c5108_row4_col0" class="data row4 col0" >f7c4243c7fe1938f181bec41a392bdeb</td>
#       <td id="T_c5108_row4_col1" class="data row4 col1" >8e6bfb81e283fa7e4f11123a3fb894f1</td>
#       <td id="T_c5108_row4_col2" class="data row4 col2" >5</td>
#     </tr>
#   </tbody>
# </table>
# shape is: (99224, 3)

# %%
display(df_orders.head().style)
print(f'shape is: {df_orders.shape}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_31769_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >order_id</th>
#       <th class="col_heading level0 col1" >customer_id</th>
#       <th class="col_heading level0 col2" >order_status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_31769_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_31769_row0_col0" class="data row0 col0" >e481f51cbdc54678b7cc49136f2d6af7</td>
#       <td id="T_31769_row0_col1" class="data row0 col1" >9ef432eb6251297304e76186b10a928d</td>
#       <td id="T_31769_row0_col2" class="data row0 col2" >delivered</td>
#     </tr>
#     <tr>
#       <th id="T_31769_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_31769_row1_col0" class="data row1 col0" >53cdb2fc8bc7dce0b6741e2150273451</td>
#       <td id="T_31769_row1_col1" class="data row1 col1" >b0830fb4747a6c6d20dea0b8c802d7ef</td>
#       <td id="T_31769_row1_col2" class="data row1 col2" >delivered</td>
#     </tr>
#     <tr>
#       <th id="T_31769_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_31769_row2_col0" class="data row2 col0" >47770eb9100c2d0c44946d9cf07ec65d</td>
#       <td id="T_31769_row2_col1" class="data row2 col1" >41ce2a54c0b03bf3443c3d931a367089</td>
#       <td id="T_31769_row2_col2" class="data row2 col2" >delivered</td>
#     </tr>
#     <tr>
#       <th id="T_31769_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_31769_row3_col0" class="data row3 col0" >949d5b44dbf5de918fe9c16f97b45f8a</td>
#       <td id="T_31769_row3_col1" class="data row3 col1" >f88197465ea7920adcdbec7375364d82</td>
#       <td id="T_31769_row3_col2" class="data row3 col2" >delivered</td>
#     </tr>
#     <tr>
#       <th id="T_31769_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_31769_row4_col0" class="data row4 col0" >ad21c59c0840e6cb83a9ceb5573f8159</td>
#       <td id="T_31769_row4_col1" class="data row4 col1" >8ab97904e6daea8866dbdbc4fb7aad2c</td>
#       <td id="T_31769_row4_col2" class="data row4 col2" >delivered</td>
#     </tr>
#   </tbody>
# </table>
# shape is: (99441, 3)

# %%
display(df_products.head().style)
print(f'shape is: {df_products.shape}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_37058_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >product_id</th>
#       <th class="col_heading level0 col1" >product_category_name</th>
#       <th class="col_heading level0 col2" >product_name_lenght</th>
#       <th class="col_heading level0 col3" >product_description_lenght</th>
#       <th class="col_heading level0 col4" >product_weight_g</th>
#       <th class="col_heading level0 col5" >product_length_cm</th>
#       <th class="col_heading level0 col6" >product_height_cm</th>
#       <th class="col_heading level0 col7" >product_width_cm</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_37058_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_
    display(dataf.describe(include='all').transpose())
    print(f'\n{dataf.info()}')
    print(f'\nContagem de nulos(%):\n{(dataf.isnull().sum().sort_values(ascending=False)/dataf.shape[0])*100}')

# %%
info_basicas(df_order_items)
# Out:
#                   count unique                               top freq  \
# order_id         112650  98666  8272b63d03f5f79c56e9e4120aec44ef   21
# order_item_id  112650.0    NaN                               NaN  NaN
# product_id       112650  32951  aca2eb7d00ea1a7b8ebd4e68314663af  527
# price          112650.0    NaN                               NaN  NaN
#
#                      mean         std   min   25%    50%    75%     max
# order_id              NaN         NaN   NaN   NaN    NaN    NaN     NaN
# order_item_id    1.197834    0.705124   1.0   1.0    1.0    1.0    21.0
# product_id            NaN         NaN   NaN   NaN    NaN    NaN     NaN
# price          120.653739  183.633928  0.85  39.9  74.99  134.9  6735.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112650 entries, 0 to 112649
# Data columns (total 4 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   order_id       112650 non-null  object
#  1   order_item_id  112650 non-null  int64
#  2   product_id     112650 non-null  object
#  3   price          112650 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 4.3+ MB
#
# None
#
# Contagem de nulos(%):
# order_id         0.0
# order_item_id    0.0
# product_id       0.0
# price            0.0
# dtype: float64

# %%
info_basicas(df_order_reviews)
# Out:
#                 count unique                               top freq      mean  \
# review_id       99224  98410  7b606b0d57b078384f0b58eac1d41d78    3       NaN
# order_id        99224  98673  c88b1d1b157a9999ce368f218a407141    3       NaN
# review_score  99224.0    NaN                               NaN  NaN  4.086421
#
#                    std  min  25%  50%  75%  max
# review_id          NaN  NaN  NaN  NaN  NaN  NaN
# order_id           NaN  NaN  NaN  NaN  NaN  NaN
# review_score  1.347579  1.0  4.0  5.0  5.0  5.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99224 entries, 0 to 99223
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   review_id     99224 non-null  object
#  1   order_id      99224 non-null  object
#  2   review_score  99224 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 3.0+ MB
#
# None
#
# Contagem de nulos(%):
# review_id       0.0
# order_id        0.0
# review_score    0.0
# dtype: float64

# %%
info_basicas(df_orders)
# Out:
#               count unique                               top   freq
# order_id      99441  99441  e481f51cbdc54678b7cc49136f2d6af7      1
# customer_id   99441  99441  9ef432eb6251297304e76186b10a928d      1
# order_status  99441      8                         delivered  96478
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99441 entries, 0 to 99440
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   order_id      99441 non-null  object
#  1   customer_id   99441 non-null  object
#  2   order_status  99441 non-null  object
# dtypes: object(3)
# memory usage: 3.0+ MB
#
# None
#
# Contagem de nulos(%):
# order_id        0.0
# customer_id     0.0
# order_status    0.0
# dtype: float64

# %%
print(f'Contagem de valores:\n{df_orders["order_status"].value_counts()}')
# Out:
# Contagem de valores:
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: order_status, dtype: int64

# %%
info_basicas(df_products)
# Out:
#                               count unique                               top  \
# product_id                    32951  32951  1e9e8ef04dbcff4541ed26657ea517e5
# product_category_name         32341     73                   cama_mesa_banho
# product_name_lenght         32341.0    NaN                               NaN
# product_description_lenght  32341.0    NaN                               NaN
# product_weight_g            32949.0    NaN                               NaN
# product_length_cm           32949.0    NaN                               NaN
# product_height_cm           32949.0    NaN                               NaN
# product_width_cm            32949.0    NaN                               NaN
#
#                             freq         mean          std  min    25%    50%  \
# product_id                     1          NaN          NaN  NaN    NaN    NaN
# product_category_name       3029          NaN          NaN  NaN    NaN    NaN
# product_name_lenght          NaN    48.476949    10.245741  5.0   42.0   51.0
# product_description_lenght   NaN   771.495285   635.115225  4.0  339.0  595.0
# product_weight_g             NaN  2276.472488  4282.038731  0.0  300.0  700.0
# product_length_cm            NaN    30.815078    16.914458  7.0   18.0   25.0
# product_height_cm            NaN    16.937661    13.637554  2.0    8.0   13.0
# product_width_cm             NaN    23.196728    12.079047  6.0   15.0   20.0
#
#                                75%      max
# product_id                     NaN      NaN
# product_category_name          NaN      NaN
# product_name_lenght           57.0     76.0
# product_description_lenght   972.0   3992.0
# product_weight_g            1900.0  40425.0
# product_length_cm             38.0    105.0
# product_height_cm             21.0    105.0
# product_width_cm              30.0    118.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32951 entries, 0 to 32950
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_weight_g            32949 non-null  float64
#  5   product_length_cm           32949 non-null  float64
#  6   product_height_cm           32949 non-null  float64
#  7   product_width_cm            32949 non-null  float64
# dtypes: float64(6), object(2)
# memory usage: 2.3+ MB
#
# None
#
# Contagem de nulos(%):
# product_category_name         1.851234
# product_name_lenght           1.851234
# product_description_lenght    1.851234
# product_weight_g              0.006070
# product_length_cm             0.006070
# product_height_cm             0.006070
# product_width_cm              0.006070
# product_id                    0.000000
# dtype: float64

# %%
print(f'Contagem de valores:\n{df_products["product_category_name"].value_counts()}')
# Out:
# Contagem de valores:
# cama_mesa_banho                  3029
# esporte_lazer                    2867
# moveis_decoracao                 2657
# beleza_saude                     2444
# utilidades_domesticas            2335
#                                  ...
# fashion_roupa_infanto_juvenil       5
# casa_conforto_2                     5
# pc_gamer                            3
# seguros_e_servicos                  2
# cds_dvds_musicais                   1
# Name: product_category_name, Length: 73, dtype: int64

# %%
df_products.dropna(inplace=True)

# %% [markdown]
# <h1><b>Recommendation model</b></h1>

# %% [markdown]
# <h2><b>Merge Datasets</b></h2>

# %%
df_int = df_order_items.merge(df_order_reviews,how='left',left_on='order_id',right_on='order_id')

# %%
display(df_int.head().style)
print(f'shape is: {df_int.shape}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_1a155_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >order_id</th>
#       <th class="col_heading level0 col1" >order_item_id</th>
#       <th class="col_heading level0 col2" >product_id</th>
#       <th class="col_heading level0 col3" >price</th>
#       <th class="col_heading level0 col4" >review_id</th>
#       <th class="col_heading level0 col5" >review_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a155_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1a155_row0_col0" class="data row0 col0" >00010242fe8c5a6d1ba2dd792cb16214</td>
#       <td id="T_1a155_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_1a155_row0_col2" class="data row0 col2" >4244733e06e7ecb4970a6e2683c13e61</td>
#       <td id="T_1a155_row0_col3" class="data row0 col3" >58.900000</td>
#       <td id="T_1a155_row0_col4" class="data row0 col4" >97ca439bc427b48bc1cd7177abe71365</td>
#       <td id="T_1a155_row0_col5" class="data row0 col5" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1a155_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1a155_row1_col0" class="data row1 col0" >00018f77f2f0320c557190d7a144bdd3</td>
#       <td id="T_1a155_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_1a155_row1_col2" class="data row1 col2" >e5f2d52b802189ee658865ca93d83a8f</td>
#       <td id="T_1a155_row1_col3" class="data row1 col3" >239.900000</td>
#       <td id="T_1a155_row1_col4" class="data row1 col4" >7b07bacd811c4117b742569b04ce3580</td>
#       <td id="T_1a155_row1_col5" class="data row1 col5" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1a155_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1a155_row2_col0" class="data row2 col0" >000229ec398224ef6ca0657da4fc703e</td>
#       <td id="T_1a155_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_1a155_row2_col2" class="data row2 col2" >c777355d18b72b67abbeef9df44fd0fd</td>
#       <td id="T_1a155_row2_col3" class="data row2 col3" >199.000000</td>
#       <td id="T_1a155_row2_col4" class="data row2 col4" >0c5b33dea94867d1ac402749e5438e8b</td>
#       <td id="T_1a155_row2_col5" class="data row2 col5" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1a155_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1a155_row3_col0" class="data row3 col0" >00024acbcdf0a6daa1e931b038114c75</td>
#       <td id="T_1a155_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_1a155_row3_col2" class="data row3 col2" >7634da152a4610f1595efa32f14722fc</td>
#       <td id="T_1a155_row3_col3" class="data row3 col3" >12.990000</td>
#       <td id="T_1a155_row3_col4" class="data row3 col4" >f4028d019cb58564807486a6aaf33817</td>
#       <td id="T_1a155_row3_col5" class="data row3 col5" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1a155_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1a155_row4_col0" class="data row4 col0" >00042b26cf59d7ce69dfabb4e55b4fd9</td>
#       <td id="T_1a155_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_1a155_row4_col2" class="data row4 col2" >ac6c3623068f30de03045865e4e10089</td>
#       <td id="T_1a155_row4_col3" class="data row4 col3" >199.900000</td>
#       <td id="T_1a155_row4_col4" class="data row4 col4" >940144190dcba6351888cafa43f3a3a5</td>
#       <td id="T_1a155_row4_col5" class="data row4 col5" >5.000000</td>
#     </tr>
#   </tbody>
# </table>
# shape is: (113314, 6)

# %%
info_basicas(df_int)
# Out:
#                   count unique                               top freq  \
# order_id         113314  98666  5a3b1c29a49756e75f1ef513383c0c12   22
# order_item_id  113314.0    NaN                               NaN  NaN
# product_id       113314  32951  aca2eb7d00ea1a7b8ebd4e68314663af  527
# price          113314.0    NaN                               NaN  NaN
# review_id        112372  97709  e8236fe7b6e1bdd513a500de361e2b87   21
# review_score   112372.0    NaN                               NaN  NaN
#
#                      mean         std   min   25%   50%    75%     max
# order_id              NaN         NaN   NaN   NaN   NaN    NaN     NaN
# order_item_id    1.198528    0.707016   1.0   1.0   1.0    1.0    21.0
# product_id            NaN         NaN   NaN   NaN   NaN    NaN     NaN
# price          120.478701  183.279678  0.85  39.9  74.9  134.9  6735.0
# review_id             NaN         NaN   NaN   NaN   NaN    NaN     NaN
# review_score     4.032473    1.387849   1.0   4.0   5.0    5.0     5.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 113314 entries, 0 to 113313
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   order_id       113314 non-null  object
#  1   order_item_id  113314 non-null  int64
#  2   product_id     113314 non-null  object
#  3   price          113314 non-null  float64
#  4   review_id      112372 non-null  object
#  5   review_score   112372 non-null  float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 6.1+ MB
#
# None
#
# Contagem de nulos(%):
# review_id        0.831318
# review_score     0.831318
# order_id         0.000000
# order_item_id    0.000000
# product_id       0.000000
# price            0.000000
# dtype: float64

# %%
df_rec_avalicao = df_products.merge(df_int,how='left',left_on='product_id',right_on='product_id')
display(df_rec_avalicao.head().style)
print(f'shape is: {df_rec_avalicao.shape}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_a3f0e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >product_id</th>
#       <th class="col_heading level0 col1" >product_category_name</th>
#       <th class="col_heading level0 col2" >product_name_lenght</th>
#       <th class="col_heading level0 col3" >product_description_lenght</th>
#       <th class="col_heading level0 col4" >product_weight_g</th>
#       <th class="col_heading level0 col5" >product_length_cm</th>
#       <th class="col_heading level0 col6" >product_height_cm</th>
#       <th class="col_heading level0 col7" >product_width_cm</th>
#       <th class="col_heading level0 col8" >order_id</th>
#       <th class="col_heading level0 col9" >order_item_id</th>
#       <th class="col_heading level0 col10" >price</th>
#       <th class="col_heading level0 col11" >review_id</th>
#       <th class="col_heading level0 col12" >review_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3f0e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a3f0e_row0_col0" class="data row0 col0" >1e9e8ef04dbcff4541ed26657ea517e5</td>
#       <td id="T_a3f0e_row0_col1" class="data row0 col1" >perfumaria</td>
#       <td id="T_a3f0e_row0_col2" class="data row0 col2" >40.000000</td>
#       <td id="T_a3f0e_row0_col3" class="data row0 col3" >287.000000</td>
#       <td id="T_a3f0e_row0_col4" class="data row0 col4" >225.000000</td>
#       <td id="T_a3f0e_row0_col5" class="data row0 col5" >16.000000</td>
#       <td id="T_a3f0e_row0_col6" class="data row0 col6" >10.000000</td>
#       <td id="T_a3f0e_row0_col7" class="data row0 col7" >14.000000</td>
#       <td id="T_a3f0e_row0_col8" class="data row0 col8" >e17e4f88e31525f7deef66779844ddce</td>
#       <td id="T_a3f0e_row0_col9" class="data row0 col9" >1</td>
#       <td id="T_a3f0e_row0_col10" class="data row0 col10" >10.910000</td>
#       <td id="T_a3f0e_row0_col11" class="data row0 col11" >d71da8fd8c6e3adef26be965f065b8a1</td>
#       <td id="T_a3f0e_row0_col12" class="data row0 col12" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a3f0e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a3f0e_row1_col0" class="data row1 col0" >3aa071139cb16b67ca9e5dea641aaa2f</td>
#       <td id="T_a3f0e_row1_col1" class="data row1 col1" >artes</td>
#       <td id="T_a3f0e_row1_col2" class="data row1 col2" >44.000000</td>
#       <td id="T_a3f0e_row1_col3" class="data row1 col3" >276.000000</td>
#       <td id="T_a3f0e_row1_col4" class="data row1 col4" >1000.000000</td>
#       <td id="T_a3f0e_row1_col5" class="data row1 col5" >30.000000</td>
#       <td id="T_a3f0e_row1_col6" class="data row1 col6" >18.000000</td>
#       <td id="T_a3f0e_row1_col7" class="data row1 col7" >20.000000</td>
#       <td id="T_a3f0e_row1_col8" class="data row1 col8" >5236307716393b7114b53ee991f36956</td>
#       <td id="T_a3f0e_row1_col9" class="data row1 col9" >1</td>
#       <td id="T_a3f0e_row1_col10" class="data row1 col10" >248.000000</td>
#       <td id="T_a3f0e_row1_col11" class="data row1 col11" >19866247db89845ef558ef19a6c26fcd</td>
#       <td id="T_a3f0e_row1_col12" class="data row1 col12" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a3f0e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a3f0e_row2_col0" class="data row2 col0" >96bd76ec8810374ed1b65e291975717f</td>
#       <td id="T_a3f0e_row2_col1" class="data row2 col1" >esporte_lazer</td>
#       <td id="T_a3f0e_row2_col2" class="data row2 col2" >46.000000</td>
#       <td id="T_a3f0e_row2_col3" class="data row2 col3" >250.000000</td>
#       <td id="T_a3f0e_row2_col4" class="data row2 col4" >154.000000</td>
#       <td id="T_a3f0e_row2_col5" class="data row2 col5" >18.000000</td>
#       <td id="T_a3f0e_row2_col6" class="data row2 col6" >9.000000</td>
#       <td id="T_a3f0e_row2_col7" class="data row2 col7" >15.000000</td>
#       <td id="T_a3f0e_row2_col8" class="data row2 col8" >01f66e58769f84129811d43eefd187fb</td>
#       <td id="T_a3f0e_row2_col9" class="data row2 col9" >1</td>
#       <td id="T_a3f0e_row2_col10" class="data row2 col10" >79.800000</td>
#       <td id="T_a3f0e_row2_col11" class="data row2 col11" >32921b4e09c9a19d61fe46ce04231b84</td>
#       <td id="T_a3f0e_row2_col12" class="data row2 col12" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a3f0e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a3f0e_row3_col0" class="data row3 col0" >cef67bcfe19066a932b7673e239eb23d</td>
#       <td id="T_a3f0e_row3_col1" class="data row3 col1" >bebes</td>
#       <td id="T_a3f0e_row3_col2" class="data row3 col2" >27.000000</td>
#       <td id="T_a3f0e_row3_col3" class="data row3 col3" >261.000000</td>
#       <td id="T_a3f0e_row3_col4" class="data row3 col4" >371.000000</td>
#       <td id="T_a3f0e_row3_col5" class="data row3 col5" >26.000000</td>
#       <td id="T_a3f0e_row3_col6" class="data row3 col6" >4.000000</td>
#       <td id="T_a3f0e_row3_col7" class="data row3 col7" >26.000000</td>
#       <td id="T_a3f0e_row3_col8" class="data row3 col8" >143d00a4f2dde4e0364ee1821577adb3</td>
#       <td id="T_a3f0e_row3_col9" class="data row3 col9" >1</td>
#       <td id="T_a3f0e_row3_col10" class="data row3 col10" >112.300000</td>
#       <td id="T_a3f0e_row3_col11" class="data row3 col11" >70949d129965fb1ee32aaccec720a19e</td>
#       <td id="T_a3f0e_row3_col12" class="data row3 col12" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a3f0e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a3f0e_row4_col0" class="data row4 col0" >9dc1a7de274444849c219cff195d0b71</td>
#       <td id="T_a3f0e_row4_col1" class="data row4 col1" >utilidades_domesticas</td>
#       <td id="T_a3f0e_row4_col2" class="data row4 col2" >37.000000</td>
#       <td id="T_a3f0e_row4_col3" class="data row4 col3" >402.000000</td>
#       <td id="T_a3f0e_row4_col4" class="data row4 col4" >625.000000</td>
#       <td id="T_a3f0e_row4_col5" class="data row4 col5" >20.000000</td>
#       <td id="T_a3f0e_row4_col6" class="data row4 col6" >17.000000</td>
#       <td id="T_a3f0e_row4_col7" class="data row4 col7" >13.000000</td>
#       <td id="T_a3f0e_row4_col8" class="data row4 col8" >86cafb8794cb99a9b1b77fc8e48fbbbb</td>
#       <td id="T_a3f0e_row4_col9" class="data row4 col9" >1</td>
#       <td id="T_a3f0e_row4_col10" class="data row4 col10" >37.900000</td>
#       <td id="T_a3f0e_row4_col11" class="data row4 col11" >74c9c7d0bc153bbbc92e4c1597b8ba55</td>
#       <td id="T_a3f0e_row4_col12" class="data row4 col12" >5.000000</td>
#     </tr>
#   </tbody>
# </table>
# shape is: (111701, 13)

# %%
df_rec_avalicao.drop(columns=['product_name_lenght',
       'product_description_lenght', 'product_weight_g', 'product_length_cm',
       'product_height_cm', 'product_width_cm', 'order_id', 'order_item_id',
       'price', 'review_id'],inplace=True)

# %%
info_basicas(df_rec_avalicao)
# Out:
#                           count unique                               top  \
# product_id               111701  32340  aca2eb7d00ea1a7b8ebd4e68314663af
# product_category_name    111701     73                   cama_mesa_banho
# review_score           110773.0    NaN                               NaN
#
#                         freq      mean      std  min  25%  50%  75%  max
# product_id               527       NaN      NaN  NaN  NaN  NaN  NaN  NaN
# product_category_name  11270       NaN      NaN  NaN  NaN  NaN  NaN  NaN
# review_score             NaN  4.035225  1.38542  1.0  4.0  5.0  5.0  5.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 111701 entries, 0 to 111700
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   product_id             111701 non-null  object
#  1   product_category_name  111701 non-null  object
#  2   review_score           110773 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 3.4+ MB
#
# None
#
# Contagem de nulos(%):
# review_score             0.830789
# product_id               0.000000
# product_category_name    0.000000
# dtype: float64

# %%
df_rec_avalicao.dropna(inplace=True)

# %%
df_rec_prod = df_products.merge(df_int,how='left',left_on='product_id',right_on='product_id')
display(df_rec_prod.head().style)
print(f'shape is: {df_rec_prod.shape}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_c5769_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >product_id</th>
#       <th class="col_heading level0 col1" >product_category_name</th>
#       <th class="col_heading level0 col2" >product_name_lenght</th>
#       <th class="col_heading level0 col3" >product_description_lenght</th>
#       <th class="col_heading level0 col4" >product_weight_g</th>
#       <th class="col_heading level0 col5" >product_length_cm</th>
#       <th class="col_heading level0 col6" >product_height_cm</th>
#       <th class="col_heading level0 col7" >product_width_cm</th>
#       <th class="col_heading level0 col8" >order_id</th>
#       <th class="col_heading level0 col9" >order_item_id</th>
#       <th class="col_heading level0 col10" >price</th>
#       <th class="col_heading level0 col11" >review_id</th>
#       <th class="col_heading level0 col12" >review_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c5769_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c5769_row0_col0" class="data row0 col0" >1e9e8ef04dbcff4541ed26657ea517e5</td>
#       <td id="T_c5769_row0_col1" class="data row0 col1" >perfumaria</td>
#       <td id="T_c5769_row0_col2" class="data row0 col2" >40.000000</td>
#       <td id="T_c5769_row0_col3" class="data row0 col3" >287.000000</td>
#       <td id="T_c5769_row0_col4" class="data row0 col4" >225.000000</td>
#       <td id="T_c5769_row0_col5" class="data row0 col5" >16.000000</td>
#       <td id="T_c5769_row0_col6" class="data row0 col6" >10.000000</td>
#       <td id="T_c5769_row0_col7" class="data row0 col7" >14.000000</td>
#       <td id="T_c5769_row0_col8" class="data row0 col8" >e17e4f88e31525f7deef66779844ddce</td>
#       <td id="T_c5769_row0_col9" class="data row0 col9" >1</td>
#       <td id="T_c5769_row0_col10" class="data row0 col10" >10.910000</td>
#       <td id="T_c5769_row0_col11" class="data row0 col11" >d71da8fd8c6e3adef26be965f065b8a1</td>
#       <td id="T_c5769_row0_col12" class="data row0 col12" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c5769_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c5769_row1_col0" class="data row1 col0" >3aa071139cb16b67ca9e5dea641aaa2f</td>
#       <td id="T_c5769_row1_col1" class="data row1 col1" >artes</td>
#       <td id="T_c5769_row1_col2" class="data row1 col2" >44.000000</td>
#       <td id="T_c5769_row1_col3" class="data row1 col3" >276.000000</td>
#       <td id="T_c5769_row1_col4" class="data row1 col4" >1000.000000</td>
#       <td id="T_c5769_row1_col5" class="data row1 col5" >30.000000</td>
#       <td id="T_c5769_row1_col6" class="data row1 col6" >18.000000</td>
#       <td id="T_c5769_row1_col7" class="data row1 col7" >20.000000</td>
#       <td id="T_c5769_row1_col8" class="data row1 col8" >5236307716393b7114b53ee991f36956</td>
#       <td id="T_c5769_row1_col9" class="data row1 col9" >1</td>
#       <td id="T
row4_col9" class="data row4 col9" >1</td>
#       <td id="T_c5769_row4_col10" class="data row4 col10" >37.900000</td>
#       <td id="T_c5769_row4_col11" class="data row4 col11" >74c9c7d0bc153bbbc92e4c1597b8ba55</td>
#       <td id="T_c5769_row4_col12" class="data row4 col12" >5.000000</td>
#     </tr>
#   </tbody>
# </table>
# shape is: (111701, 13)

# %%
info_basicas(df_rec_prod)
# Out:
#                                count unique                               top  \
# product_id                    111701  32340  aca2eb7d00ea1a7b8ebd4e68314663af
# product_category_name         111701     73                   cama_mesa_banho
# product_name_lenght         111701.0    NaN                               NaN
# product_description_lenght  111701.0    NaN                               NaN
# product_weight_g            111701.0    NaN                               NaN
# product_length_cm           111701.0    NaN                               NaN
# product_height_cm           111701.0    NaN                               NaN
# product_width_cm            111701.0    NaN                               NaN
# order_id                      111701  97276  5a3b1c29a49756e75f1ef513383c0c12
# order_item_id               111701.0    NaN                               NaN
# price                       111701.0    NaN                               NaN
# review_id                     110773  96340  e8236fe7b6e1bdd513a500de361e2b87
# review_score                110773.0    NaN                               NaN
#
#                              freq         mean          std   min    25%  \
# product_id                    527          NaN          NaN   NaN    NaN
# product_category_name       11270          NaN          NaN   NaN    NaN
# product_name_lenght           NaN    48.777459    10.024605   5.0   42.0
# product_description_lenght    NaN   786.898551   651.761742   4.0  348.0
# product_weight_g              NaN  2098.139918  3752.850523   0.0  300.0
# product_length_cm             NaN    30.219327    16.186944   7.0   18.0
# product_height_cm             NaN    16.616673    13.462724   2.0    8.0
# product_width_cm              NaN    23.048889      11.7175   6.0   15.0
# order_id                       22          NaN          NaN   NaN    NaN
# order_item_id                 NaN     1.198933     0.708805   1.0    1.0
# price                         NaN   120.587213   182.985746  0.85   39.9
# review_id                      21          NaN          NaN   NaN    NaN
# review_score                  NaN     4.035225      1.38542   1.0    4.0
#
#                               50%     75%      max
# product_id                    NaN     NaN      NaN
# product_category_name         NaN     NaN      NaN
# product_name_lenght          52.0    57.0     76.0
# product_description_lenght  601.0   985.0   3992.0
# product_weight_g            700.0  1800.0  40425.0
# product_length_cm            25.0    38.0    105.0
# product_height_cm            13.0    20.0    105.0
# product_width_cm             20.0    30.0    118.0
# order_id                      NaN     NaN      NaN
# order_item_id                 1.0     1.0     21.0
# price                        74.9   134.9   6735.0
# review_id                     NaN     NaN      NaN
# review_score                  5.0     5.0      5.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 111701 entries, 0 to 111700
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   product_id                  111701 non-null  object
#  1   product_category_name       111701 non-null  object
#  2   product_name_lenght         111701 non-null  float64
#  3   product_description_lenght  111701 non-null  float64
#  4   product_weight_g            111701 non-null  float64
#  5   product_length_cm           111701 non-null  float64
#  6   product_height_cm           111701 non-null  float64
#  7   product_width_cm            111701 non-null  float64
#  8   order_id                    111701 non-null  object
#  9   order_item_id               111701 non-null  int64
#  10  price                       111701 non-null  float64
#  11  review_id                   110773 non-null  object
#  12  review_score                110773 non-null  float64
# dtypes: float64(8), int64(1), object(4)
# memory usage: 11.9+ MB
#
# None
#
# Contagem de nulos(%):
# review_id                     0.830789
# review_score                  0.830789
# product_id                    0.000000
# product_category_name         0.000000
# product_name_lenght           0.000000
# product_description_lenght    0.000000
# product_weight_g              0.000000
# product_length_cm             0.000000
# product_height_cm             0.000000
# product_width_cm              0.000000
# order_id                      0.000000
# order_item_id                 0.000000
# price                         0.000000
# dtype: float64

# %%
df_rec_prod.dropna(inplace=True)

# %% [markdown]
# <h2><b>Recommendation of the most purchased items by category</b></h2>

# %% [markdown]
# This model can be used for the categories' first page when a user enter on the page the model will return the list of the most purchased products

# %%
def start_pipeline(dataf):
    d = dataf.copy()
    return d

def product_count(d, n):
    x = pd.pivot_table(df_rec_avalicao,index=['product_category_name', 'product_id'],\
                        aggfunc={'product_id':pd.Series.value_counts})\
    .rename(columns={'product_id':'product_id_count'}) \
    .sort_values(['product_category_name','product_id_count'], ascending = False)\
    .reset_index()
    y = x.groupby(by='product_category_name').head(n).reset_index(drop=True)
    return y

def dicio(y):
    categories = top_products.product_category_name.unique()
    dict_categories = {category: top_products[top_products.product_category_name==category]\
                       .product_id.unique().tolist() for category in categories}
    return dict_categories

# %%
top_products = df_rec_avalicao \
    .pipe(start_pipeline) \
    .pipe(product_count, n=5) \
    .pipe(dicio)

# %%
top_products
# Out:
# {'utilidades_domesticas': ['42a2c92a0979a949ca4ea89ec5c7b934',
#   '5a6e53c3b4e8684b13388d6aa4afdf12',
#   'f7a17d2c51d9df89a4f1711c4ac17f33',
#   '928e52a9ad53a294fdcc91bcf59d1751',
#   'e9a69340883a438c3f91739d14d3a56d'],
#  'telefonia_fixa': ['913580fde3e72c3b3e4ce0b79963bee6',
#   'b4f9530c931398e215242293c2c8ba4c',
#   '4633dfeb3a2588bdb52af32d504b44eb',
#   'db51982bc43b26164c29605b8ed140d6',
#   'f07ef9dd6e2d9a366ff30a25e210be70'],
#  'telefonia': ['e7cc48a9daff5436f63d3aad9426f28b',
#   'c9c6fde711572c1ad99ca12728c6af00',
#   '97017430754804328eb9597b7f85da03',
#   'dab2413ead0edda9967edbc9bda2a64e',
#   '8c5876b1c7768217964f353bc7e64393'],
#  'tablets_impressao_imagem': ['6bbe55cf8f85c87b6eebb775a53402f4',
#   '34dabb8af33b3756cf72df05fb327011',
#   '2eb9b2ef7c1da3c7b99702452ea4729f',
#   '3c46d3f68a377931cdadfd72c6158643',
#   'ab0a97f604550b5b5b99180a6dc04461'],
#  'sinalizacao_e_seguranca': ['150c699262a053229e89213dc9c358d2',
#   '0c8b6b6e4f9ee5fe2c48d6cee4c69bc8',
#   '7d8e924f1da646ec896e1c0a80ef2f99',
#   '49e038a7b8ba2e18d9a7a26c1f238544',
#   '5d3b065e160c51e883cd7ef509a54176'],
#  'seguros_e_servicos': ['6c7a0a349ad11817745e3ad58abd5c79',
#   '8db75af9aed3315374db44d7860e25da'],
#  'relogios_presentes': ['53b36df67ebb7c41585e8d54d6772e08',
#   'a62e25e09e05e6faf31d90c6ec1aa3d1',
#   'e0d64dcfaa3b6db5c54ca298ae101d05',
#   'a92930c327948861c015c919a0bcb4a8',
#   '461f43be3bdf8844e65b62d9ac2c7a5a'],
#   '1ec486885049bbb9b79351d150ed18c4',
#   '87283a98b24f9f1ac3a31b631073cf47',
#   'ccadfeab525a9eb1569983b66e5075c4',
#   '44d097d59e8430f88a67517cd0c4f865'],
#  'esporte_lazer': ['c6336fa91fbd87c359e44f5dca5a90ed',
#   'e44f675b60b3a3a2453ec36421e06f0f',
#   '362b773250263786dd58670d2df42c3b',
#   'cec09725da5ed01471d9a505e7389d37',
#   'd3c044bd42d84a79e3b0c42662806a48'],
#  'eletroportateis': ['79366d6a24de9351b7ca6e3cf75a68ec',
#   '63d6e7ab30f482382c9dfbbccae7da54',
#   '44fc450365728c413fefc547592626be',
#   'a5e537da8376b8623758e0186bfa400f',
#   'd2bea3c01e172037caa99b2d138f39d0'],
#  'eletronicos': ['7ce94ab189134e2d3c05f496d635419c',
#   '93c902b021a9e594f658ab1b0351602a',
#   'ab1f9387c0627dd24000bfbc54fdeee0',
#   '5d66715cc928aadd0074f61332698593',
#   '6a8631b72a2f8729b91514db87e771c0'],
#  'eletrodomesticos_2': ['f27aff266ad97e75d4a24c893b2c311e',
#   '2d063994ae4667cff3d6841e9d441d1d',
#   '7fe486a60125c1541517e30944f95066',
#   '99c97d191bcc87e072acc4521bce44d4',
#   'c3182d1991c7d4859e8f39b6c45a026b'],
#  'eletrodomesticos': ['e5eadf9be70a4a9fa514019542fc330a',
#   'be837f2e0152a208d4386f4126d5bd7c',
#   '50d77758742285ff49f340ebdf0df5a7',
#   'b30d7b0adcdc4a117f455472548155ec',
#   'ab5da1daa941470d14366f4e76a99dd2'],
#  'dvds_blu_ray': ['8ac47b3ab13c68f49f10dde899674149',
#   'd55d2479e56093f23ebcf313ceb3bcfe',
#   '133f594a246e5c52489304a4b5a39830',
#   '6f19f41a7c7ac7e45f4070d07ed80a75',
#   '2d31f67b1edd83be73d1448bc1f1a7c7'],
#  'cool_stuff': ['c6dd917a0be2a704582055949915ab32',
#   '601a360bd2a916ecef0e88de72a6531a',
#   '54d9ac713e253fa1fae9c8003b011c2a',
#   '165f86fe8b799a708a20ee4ba125c289',
#   '29427de7f8a9ee983d9dbc51cec569b4'],
#  'construcao_ferramentas_seguranca': ['82c51c3938503a4ddc096fbed86428d6',
#   '56c221c4c1a4a98293895c4563cdc6bf',
#   '88ffcf27478318ba55b1f9d22d65ce97',
#   '3b473a6b1c280e0345e876648a61a032',
#   '3b91132e7eebaa17b615edbcdb5baa8e'],
#  'construcao_ferramentas_jardim': ['71a7800a633691de8ecdd17463335e2e',
#   '42749c525c90994bd3d4c74edf047172',
#   '84c79830527ae823029ee6b904cf948c',
#   '0b01a9718a61dbdd35cfec9ad13a0301',
#   '4ce6c1b5cfe26c9f980438fc1c810f8d'],
#  'construcao_ferramentas_iluminacao': ['a02d0123079f4ae96001ba2010d1a2df',
#   '349ce46a0e2e20054aa9d80c48af8816',
#   '216bb0e0cd43ffd832e0973d35e0377e',
#   '26b2a480ced2900a62bb9431133e95aa',
#   '783caabd539c4079ec08423e30719fba'],
#  'construcao_ferramentas_ferramentas': ['5e53af05c040b01584b81b3549945faf',
#   'e5f20b4eb944eaae0a13bed3187201d3',
#   'd19c5ff1a4d4e8b0558536d57cf43cf7',
#   '04433a8021475a2002663f94203c88da',
#   '2c8e38b2b220b65a306d88444defb4fd'],
#  'construcao_ferramentas_construcao': ['7564c1759c04fc0a38f2aa84f7a370ee',
#   '0da9ffd92214425d880de3f94e74ce39',
#   '779dd392d4fbe5ca656bf3ceabecbf0b',
#   'f5badee8a0e679f057ec0ca4f0f32dcb',
#   'ed00a8453145186b3f071f1e3edef33d'],
#  'consoles_games': ['0aabfb375647d9738ad0f7b4ea3653b1',
#   '6c3effec7c8ddba466d4f03f982c7aa3',
#   '2bd9b51a9ab079e095aca987845d3266',
#   '4deb009c36a910076a023947a7929201',
#   'f39a8b27ce90ac582103bf36f09690dd'],
#  'climatizacao': ['98e91d0f32954dcd8505875bb2b42cdb',
#   'ccb162ed569f47d83f62aebd5700d7ad',
#   '0e34187d4312b97b5e698836d28ed040',
#   'e932008cf0ea7c93a077dd8d7e5f49eb',
#   'f2a1b32f85cad59ff2a8444154ac25f0'],
#  'cine_foto': ['e988092a8afe5d9393a5c3a7ca17691c',
#   'c3798d484fb730f0b5c23af0d5361595',
#   '1f5f0f003ce8595ad88fb215ec1409e6',
#   '88a1223b29fac4c3abef8d1369dbbaea',
#   'd55487f6b9833914549348cc2839f9e9'],
#  'cds_dvds_musicais': ['1dceebcc5f23c02ea23e16d5bedca000'],
#  'casa_construcao': ['a39cc58c1b5926b6f9f378daa89f1315',
#   '679a3e5e1d2bb68982be5734c6e55e63',
#   '10070e29929f7c7d609ee3201f236b8e',
#   '71540d636652fc682032d3b3c0a180c1',
#   '3cce0d166c3fb2507956c630c1d0f87c'],
#  'casa_conforto_2': ['ec5b3c8bb77ad22278f6e9d719a83de3',
#   '15dc5bc6f0f1e1a0d0255098726060c7',
#   '19de58ea609a59ce31f93672af50c09a',
#   '2072d4792ab7893ddbfc178948e0eb86',
#   '4fb3bad6b502eaca3b6d7d87bc1613a4'],
#  'casa_conforto': ['35afc973633aaeb6b877ff57b2793310',
#   'c6bf8cc852eee5c4ab264e792a9c23a1',
#   '186052b3f166a0f7227e78b2d27652d3',
#   'e2fcaac49de7a3a90f0dc74d7b1e9f10',
#   '12fd8665371236b5b586ea4e448902c8'],
#  'cama_mesa_banho': ['99a4788cb24856965c36a24e339b6058',
#   'f1c7f353075ce59d8a6f3cf58f419c9c',
#   '06edb72f1e0c64b14c5b79353f7abea3',
#   'ec2d43cc59763ec91694573b31f1c29a',
#   '84f456958365164420cfc80fbe4c7fab'],
#  'brinquedos': ['880be32f4db1d9f6e2bec38fb6ac23ab',
#   'b5e13c9a353102f79c6206ff5cb61a50',
#   'b623b7cb05ee3248fbe4a6ecbeed79a4',
#   '7fab1a1472fdd934397068931f63f3ca',
#   'aa280035c50ba62c746480a59045eec4'],
#   'f0c1c1d5ec61ce4c4846abd4283631df'],
#  'agro_industria_e_comercio': ['11250b0d4b709fee92441c5f34122aed',
#   '423a6644f0aa529e8828ff1f91003690',
#   '672e757f331900b9deea127a2a7b79fd',
#   '3bebad3cf2c8d1a8d3ce97174643e054',
#   'a0fe1efb855f3e786f0650268cd77f44']}

# %% [markdown]
# <h2><b>Recommendation of product similarity</b></h2>

# %% [markdown]
# This model should be used on shopping cart's page to recommend similar products for the user

# %%
df_rec_prod.drop(columns=['order_id', 'order_item_id','review_id'],inplace=True)

# %%
valores = ['product_name_lenght','product_description_lenght', 'product_weight_g',
           'product_length_cm','product_height_cm', 'product_width_cm', 'price', 'review_score']
grupo = ['product_id','product_category_name']

# %%
df_agrupado = df_rec_prod.groupby(by=grupo, as_index=False)[valores].mean()
df_agrupado
# Out:
#                              product_id        product_category_name  \
# 0      00066f42aeeb9f3007548bb9d3f33c38                   perfumaria
# 1      00088930e925c41fd95ebfe695fd2655                   automotivo
# 2      0009406fd7479715e4bef61dd91f2462              cama_mesa_banho
# 3      000b8f95fcb9e0096488278317764d19        utilidades_domesticas
# 4      000d9be29b5207b54e86aa1b1ac54872           relogios_presentes
# ...                                 ...                          ...
# 32178  fff6177642830a9a94a0f2cba5e476d1                   cool_stuff
# 32179  fff81cc3158d2725c0655ab9ba0f712c                 beleza_saude
# 32180  fff9553ac224cec9d15d49f5a263411f  fashion_bolsas_e_acessorios
# 32181  fffdb2d0ec8d6a61f0a0a0db3f25b441       informatica_acessorios
# 32182  fffe9eeff12fcbd74a2f2b007dde0c58                   brinquedos
#
#        product_name_lenght  product_description_lenght  product_weight_g  \
# 0                     53.0                       596.0             300.0
# 1                     56.0                       752.0            1225.0
# 2                     50.0                       266.0             300.0
# 3                     25.0                       364.0             550.0
# 4                     48.0                       613.0             250.0
# ...                    ...                         ...               ...
# 32178                 54.0                       842.0            1400.0
# 32179                 54.0                       643.0              58.0
# 32180                 22.0                       328.0             150.0
# 32181                 47.0                       501.0             150.0
# 32182                 57.0                      1536.0            3900.0
#
#        product_length_cm  product_height_cm  product_width_cm   price  \
# 0                   20.0               16.0              16.0  101.65
# 1                   55.0               10.0              26.0  129.90
# 2                   45.0               15.0              35.0  229.00
# 3                   19.0               24.0              12.0   58.90
# 4                   22.0               11.0              15.0  199.00
# ...                  ...                ...               ...     ...
# 32178               42.0               25.0              15.0  114.99
# 32179               16.0               16.0              11.0   90.00
# 32180               16.0               13.0              11.0   32.00
# 32181               16.0                4.0              13.0   33.99
# 32182               43.0               16.0              11.0  249.99
#
#        review_score
# 0               5.0
# 1               4.0
# 2               1.0
# 3               5.0
# 4               5.0
# ...             ...
# 32178           4.5
# 32179           4.0
# 32180           5.0
# 32181           5.0
# 32182           4.0
#
# [32183 rows x 10 columns]

# %%
df_agrupado = pd.get_dummies(df_agrupado, columns=['product_category_name'])

# %%
df_agrupado = df_agrupado.set_index('product_id')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-234-cfb723fdf18d> in <module>
# ----> 1 df_agrupado = df_agrupado.set_index('product_id')
#       2 df_agrupado
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5444
#    5445         if missing:
# -> 5446             raise KeyError(f"None of {missing} are in the columns")
#    5447
#    5448         if inplace:
#
# KeyError: "None of ['product_id'] are in the columns"

# %%
df_agrupado
# Out:
#                                   product_name_lenght  \
# product_id
# 00066f42aeeb9f3007548bb9d3f33c38                 53.0
# 00088930e925c41fd95ebfe695fd2655                 56.0
# 0009406fd7479715e4bef61dd91f2462                 50.0
# 000b8f95fcb9e0096488278317764d19                 25.0
# 000d9be29b5207b54e86aa1b1ac54872                 48.0
# ...                                               ...
# fff6177642830a9a94a0f2cba5e476d1                 54.0
# fff81cc3158d2725c0655ab9ba0f712c                 54.0
# fff9553ac224cec9d15d49f5a263411f                 22.0
# fffdb2d0ec8d6a61f0a0a0db3f25b441                 47.0
# fffe9eeff12fcbd74a2f2b007dde0c58                 57.0
#
#                                   product_description_lenght  \
# product_id
# 00066f42aeeb9f3007548bb9d3f33c38                       596.0
# 00088930e925c41fd95ebfe695fd2655                       752.0
# 0009406fd7479715e4bef61dd91f2462                       266.0
# 000b8f95fcb9e0096488278317764d19                       364.0
# 000d9be29b5207b54e86aa1b1ac54872                       613.0
# ...                                                      ...
# fff6177642830a9a94a0f2cba5e476d1                       842.0
# fff81cc3158d2725c0655ab9ba0f712c                       643.0
# fff9553ac224cec9d15d49f5a263411f                       328.0
# fffdb2d0ec8d6a61f0a0a0db3f25b441                       501.0
# fffe9eeff12fcbd74a2f2b007dde0c58                      1536.0
#
#                                   product_weight_g  product_length_cm  \
# product_id
# 00066f42aeeb9f3007548bb9d3f33c38             300.0               20.0
# 00088930e925c41fd95ebfe695fd2655            1225.0               55.0
# 0009406fd7479715e4bef61dd91f2462             300.0               45.0
# 000b8f95fcb9e0096488278317764d19             550.0               19.0
# 000d9be29b5207b54e86aa1b1ac54872             250.0               22.0
# ...                                            ...                ...
# fff6177642830a9a94a0f2cba5e476d1            1400.0               42.0
# fff81cc3158d2725c0655ab9ba0f712c              58.0               16.0
# fff9553ac224cec9d15d49f5a263411f             150.0               16.0
# fffdb2d0ec8d6a61f0a0a0db3f25b441             150.0               16.0
# fffe9eeff12fcbd74a2f2b007dde0c58            3900.0               43.0
#
#                                   product_height_cm  product_width_cm   price  \
# product_id
# 00066f42aeeb9f3007548bb9d3f33c38               16.0              16.0  101.65
# 00088930e925c41fd95ebfe695fd2655               10.0              26.0  129.90
# 0009406fd7479715e4bef61dd91f2462               15.0              35.0  229.00
# 000b8f95fcb9e0096488278317764d19               24.0              12.0   58.90
# 000d9be29b5207b54e86aa1b1ac54872               11.0              15.0  199.00
# ...                                             ...               ...     ...
# fff6177642830a9a94a0f2cba5e476d1               25.0              15.0  114.99
# fff81cc3158d2725c0655ab9ba0f712c               16.0              11.0   90.00
# fff9553ac224cec9d15d49f5a263411f               13.0              11.0   32.00
# fffdb2d0ec8d6a61f0a0a0db3f25b441                4.0              13.0   33.99
# fffe9eeff12fcbd74a2f2b007dde0c58               16.0              11.0  249.99
#
#                                   review_score  \
# product_id
# 00066f42aeeb9f3007548bb9d3f33c38           5.0
# 00088930e925c41fd95ebfe695fd2655           4.0
# 0009406fd7479715e4bef61dd91f2462           1.0
# 000b8f95fcb9e0096488278317764d19           5.0
# 000d9be29b5207b54e86aa1b1ac54872           5.0
# ...                                        ...
# fff6177642830a9a94a0f2cba5e476d1           4.5
# fff81cc3158d2725c0655ab9ba0f712c           4.0
# fff9553ac224cec9d15d49f5a263411f           5.0
# fffdb2d0ec8d6a61f0a0a0db3f25b441           5.0
# fffe9eeff12fcbd74a2f2b007dde0c58           4.0
#
#                                   product_category_name_agro_industria_e_comercio  \
# product_id
# 00066f42aeeb9f3007548bb9d3f33c38                

# fffdb2d0ec8d6a61f0a0a0db3f25b441                                     0
# fffe9eeff12fcbd74a2f2b007dde0c58                                     0
#
#                                   product_category_name_utilidades_domesticas
# product_id
# 00066f42aeeb9f3007548bb9d3f33c38                                            0
# 00088930e925c41fd95ebfe695fd2655                                            0
# 0009406fd7479715e4bef61dd91f2462                                            0
# 000b8f95fcb9e0096488278317764d19                                            1
# 000d9be29b5207b54e86aa1b1ac54872                                            0
# ...                                                                       ...
# fff6177642830a9a94a0f2cba5e476d1                                            0
# fff81cc3158d2725c0655ab9ba0f712c                                            0
# fff9553ac224cec9d15d49f5a263411f                                            0
# fffdb2d0ec8d6a61f0a0a0db3f25b441                                            0
# fffe9eeff12fcbd74a2f2b007dde0c58                                            0
#
# [32183 rows x 81 columns]

# %%
cos_prod = cosine_similarity(df_agrupado)
cos_prod
# Out:
# array([[1.        , 0.85078958, 0.87043025, ..., 0.99698558, 0.98111283,
#         0.74317227],
#        [0.85078958, 1.        , 0.89186488, ..., 0.83169918, 0.74715639,
#         0.98348391],
#        [0.87043025, 0.89186488, 1.        , ..., 0.83421717, 0.76919158,
#         0.83475904],
#        ...,
#        [0.99698558, 0.83169918, 0.83421717, ..., 1.        , 0.98942305,
#         0.71988688],
#        [0.98111283, 0.74715639, 0.76919158, ..., 0.98942305, 1.        ,
#         0.61792243],
#        [0.74317227, 0.98348391, 0.83475904, ..., 0.71988688, 0.61792243,
#         1.        ]])

# %%
prod_semelhantes = df_agrupado.index[3]

print(f'O produto escolhido é: {prod_semelhantes}')

prod_id = df_agrupado.index.tolist().index(prod_semelhantes)
print(f'Produto: {prod_semelhantes}, tem índice: {prod_id}')

similares_10 = np.argsort(-cos_prod[prod_id])[1:10]

for i in zip(df_agrupado.index[similares_10],cos_prod[prod_id][similares_10]):
  print(f'Produto {i[0]} tem similaridade {i[1]:2f} com produto {prod_semelhantes}')
# Out:
# O produto escolhido é: 000b8f95fcb9e0096488278317764d19
# Produto: 000b8f95fcb9e0096488278317764d19, tem índice: 3
# Produto 8481b767d90ff5c67263520bf912b6c4 tem similaridade 0.999816 com produto 000b8f95fcb9e0096488278317764d19
# Produto e706d603c40437249cea9606699273a7 tem similaridade 0.999793 com produto 000b8f95fcb9e0096488278317764d19
# Produto 434487f82b5c35646bd8155cf1946179 tem similaridade 0.999773 com produto 000b8f95fcb9e0096488278317764d19
# Produto cab49aa7c76189e7e6d55ad8c7f9eb91 tem similaridade 0.999742 com produto 000b8f95fcb9e0096488278317764d19
# Produto a253b2e86bb4a6f86fa11e1270e79885 tem similaridade 0.999740 com produto 000b8f95fcb9e0096488278317764d19
# Produto 4cb6e86e1328e77e20b5f90771683cbe tem similaridade 0.999730 com produto 000b8f95fcb9e0096488278317764d19
# Produto 31ec3a565e06de4bdf9d2a511b822b4d tem similaridade 0.999713 com produto 000b8f95fcb9e0096488278317764d19
# Produto cf9c9be3acfd11d21417d468511f57b1 tem similaridade 0.999705 com produto 000b8f95fcb9e0096488278317764d19
# Produto 84d0e98e468edffdfe4f1f5b178d4ecc tem similaridade 0.999669 com produto 000b8f95fcb9e0096488278317764d19
